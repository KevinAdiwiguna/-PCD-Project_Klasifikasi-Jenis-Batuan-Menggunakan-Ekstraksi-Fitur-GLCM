# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinAdiwiguna/-PCD-Project_Klasifikasi-Jenis-Batuan-Menggunakan-Ekstraksi-Fitur-GLCM/blob/main/ProjectPcd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import pandas as pd
import os
